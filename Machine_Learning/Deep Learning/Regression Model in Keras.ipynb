# %% [markdown]
# ## Peer-graded Assignment - Build a Regression Model in Keras
#
# I took the follwoing part from one of the lab assignments.

# %%
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
concrete_data_columns = concrete_data.columns

X = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
y = concrete_data['Strength'] # Strength column

# %%
X.head()
n_cols = X.shape[1] # number of predictors

# %%
from keras.models import Sequential
from keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### A. Build a baseline model (5 marks)
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the
# train_test_split
# helper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.
#
# Submit your Jupyter Notebook with your code and comments.

# %%
list_mse_1 = []

for i in range(50):
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=50)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    list_mse_1.append(mse)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 571us/step - loss: 62731.8594
# Epoch 2/50
# 23/23 [==============================] - 0s 424us/step - loss: 15115.9824
# Epoch 3/50
#  1/23 [>.............................] - ETA: 0s - loss: 5426.3975
# 2023-10-24 13:10:22.534538: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 23/23 [==============================] - 0s 508us/step - loss: 6180.6562
# Epoch 4/50
# 23/23 [==============================] - 0s 455us/step - loss: 5364.0557
# Epoch 5/50
# 23/23 [==============================] - 0s 405us/step - loss: 4820.5537
# Epoch 6/50
# 23/23 [==============================] - 0s 424us/step - loss: 4350.2974
# Epoch 7/50
# 23/23 [==============================] - 0s 441us/step - loss: 3946.5715
# Epoch 8/50
# 23/23 [==============================] - 0s 375us/step - loss: 3592.9458
# Epoch 9/50
# 23/23 [==============================] - 0s 435us/step - loss: 3283.9614
# Epoch 10/50
# ...

# %%
mean_mse_1 = np.mean(list_mse_1)
std_mse_1 = np.std(list_mse_1)

print("Mean MSE: " + str(mean_mse_1))
print("Standard Deviation of MSE: " + str(std_mse_1))
# Out:
# Mean MSE: 409.76691975213953
# Standard Deviation of MSE: 770.0151318959645

# %% [markdown]
# ### B. Normalize the data (5 marks)
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %%
X = (X - X.mean()) / X.std()

# %%
list_mse_2 = []

for i in range(50):
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=50)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    list_mse_2.append(mse)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 493us/step - loss: 1559.8062
# Epoch 2/50
# 23/23 [==============================] - 0s 440us/step - loss: 1542.9431
# Epoch 3/50
# 23/23 [==============================] - 0s 489us/step - loss: 1526.6666
# Epoch 4/50
# 23/23 [==============================] - 0s 451us/step - loss: 1510.2042
# Epoch 5/50
# 23/23 [==============================] - 0s 390us/step - loss: 1494.2603
# Epoch 6/50
# 23/23 [==============================] - 0s 410us/step - loss: 1477.6924
# Epoch 7/50
# 23/23 [==============================] - 0s 402us/step - loss: 1461.5352
# Epoch 8/50
# 23/23 [==============================] - 0s 407us/step - loss: 1445.0752
# Epoch 9/50
# 23/23 [==============================] - 0s 434us/step - loss: 1428.3887
# Epoch 10/50
# 23/23 [==============================] - 0s 422us/step - loss: 1411.2708
# Epoch 11/50
# 23/23 [==============================] - 0s 400us/step - loss: 1393.8977
# Epoch 12/50
# ...

# %%
mean_mse_2 = np.mean(list_mse_2)
std_mse_2 = np.std(list_mse_2)

print("Mean MSE: " + str(mean_mse_2))
print("Standard Deviation of MSE: " + str(std_mse_2))
# Out:
# Mean MSE: 361.8923175431766
# Standard Deviation of MSE: 105.01286613546098

# %% [markdown]
# ### C. Increate the number of epochs (5 marks)
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
list_mse_3 = []

for i in range(50):
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=100)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    list_mse_3.append(mse)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 0s 451us/step - loss: 1583.0255
# Epoch 2/100
# 23/23 [==============================] - 0s 498us/step - loss: 1568.4424
# Epoch 3/100
# 23/23 [==============================] - 0s 434us/step - loss: 1554.1519
# Epoch 4/100
# 23/23 [==============================] - 0s 443us/step - loss: 1539.8124
# Epoch 5/100
# 23/23 [==============================] - 0s 413us/step - loss: 1525.2681
# Epoch 6/100
# 23/23 [==============================] - 0s 399us/step - loss: 1510.2990
# Epoch 7/100
# 23/23 [==============================] - 0s 402us/step - loss: 1494.8156
# Epoch 8/100
# 23/23 [==============================] - 0s 396us/step - loss: 1478.3062
# Epoch 9/100
# 23/23 [==============================] - 0s 420us/step - loss: 1461.2188
# Epoch 10/100
# 23/23 [==============================] - 0s 368us/step - loss: 1442.8982
# Epoch 11/100
# 23/23 [==============================] - 0s 403us/step - loss: 1423.3995
# Epoch 12/100
# ...

# %%
mean_mse_3 = np.mean(list_mse_3)
std_mse_3 = np.std(list_mse_3)

print("Mean MSE: " + str(mean_mse_3))
print("Standard Deviation of MSE: " + str(std_mse_3))
# Out:
# Mean MSE: 161.95394794403404
# Standard Deviation of MSE: 14.6420905735304

# %% [markdown]
# ### D. Increase the number of hidden layers (5 marks)
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
list_mse_4 = []

for i in range(50):
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    model.fit(X_train, y_train, epochs=100)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    list_mse_4.append(mse)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 0s 509us/step - loss: 1552.8953
# Epoch 2/100
# 23/23 [==============================] - 0s 509us/step - loss: 1524.2885
# Epoch 3/100
# 23/23 [==============================] - 0s 463us/step - loss: 1494.2227
# Epoch 4/100
# 23/23 [==============================] - 0s 523us/step - loss: 1451.7858
# Epoch 5/100
# 23/23 [==============================] - 0s 451us/step - loss: 1392.1669
# Epoch 6/100
# 23/23 [==============================] - 0s 405us/step - loss: 1308.1486
# Epoch 7/100
# 23/23 [==============================] - 0s 415us/step - loss: 1193.3114
# Epoch 8/100
# 23/23 [==============================] - 0s 442us/step - loss: 1044.1239
# Epoch 9/100
# 23/23 [==============================] - 0s 436us/step - loss: 865.2985
# Epoch 10/100
# 23/23 [==============================] - 0s 433us/step - loss: 677.6898
# Epoch 11/100
# 23/23 [==============================] - 0s 461us/step - loss: 512.7034
# Epoch 12/100
# ...

# %%
mean_mse_4 = np.mean(list_mse_4)
std_mse_4 = np.std(list_mse_4)

print("Mean MSE: " + str(mean_mse_4))
print("Standard Deviation of MSE: " + str(std_mse_4))
# Out:
# Mean MSE: 90.90752185345607
# Standard Deviation of MSE: 21.801782280594562
